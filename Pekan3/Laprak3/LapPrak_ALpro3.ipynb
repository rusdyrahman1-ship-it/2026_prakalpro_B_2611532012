# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA DAN PEMROGRAMAN DATA**
#
# **“Operator Python”**
#
# **Disusun Oleh :**
#
# **Muhammad Rusdy Rahman**
#
# **2611532012**
#
# **Dosen Pengampu:**
#
# **Dr. Ir WAHYUDI, ST., MT.**
#
# **Asisten Praktikum:**
#
# **Rifky Yuliandra**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji beserta syukur saya panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga saya dapat menyelesaikan laporan praktikum mengenai pengenalan Operator Python yang telah dilaksanakan sebagai pertemuan ke-3 untuk mata kuliah Praktikum Algoritma dan Pemrograman. Praktikum ini berfokus pada pembahasan jenis - jenis operator apa saja yang ada pada bahasa pemrograman Python.
#
# Melalui praktikum ini, hasil yang diharapkan adalah saya dapat memahami secara langsung konsep mengenai operator - operator yang terdapat di dalam Python serta penggunaan operator = operator tersebut pada bahasa pemrograman Python.
#
# Saya menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Perkembangan zaman teknologi informasi membuat pengolahan data dan pembuatan sistem semakin dibutuhkan di zaman sekarang. Bahasa pemrograman yang sering digunakan adalah Python. Python menggunakan sintaks yang sederhana. Selain itu, Python digunakan untuk membuat program sistem, pengolahan data, dan pengembangan kecerdasan buatan. Dan juga, Python merupakan bahasa pemrograman paling berkembang di zaman sekarang. Oleh karena itu, hendaknya untuk memahami dasar-dasar Python untuk menjadi dasar untuk mempelajari cara membuat program di kemudian hari.
#
# Dasar-dasar pemrograman yang harus dipelajari adalah operator. Operator adalah simbol khusus yang digunakan untuk melakukan suatu operasi atau perhitungan terhadap satu atau lebih nilai (operand). Dengan adanya operator, data yang ada di dalam program dapat diolah, dibandingkan, maupun digabungkan sesuai dengan kebutuhan logika program.
#
# Selain itu, terdapat pula beberapa jenis operator yang menjadi dasar-dasar dari pemrograman. Jenis operator menunjukkan fungsi apa yang sedang kita gunakan, seperti operator aritmatika untuk perhitungan matematis (+, -, *, /), operator perbandingan untuk membandingkan dua nilai (==, !=, >, <), operator logika untuk mengambil keputusan (and, or, not, xor), operator penegasan digunakan untuk data sama persis dalam memori, dan operator bitwise yang digunakan untuk mempresentasikan bit (biner).
#
# ## 1.2 Tujuan
# 1. Memahami konsep dasar operator dalam Python.
# 2. Mengenali jenis-jenis operator (aritmatika, perbandingan, logika, dan penugasan).
# 3. Mengimplementasikan penggunaan operator dalam program sederhana.
# 4. Menganalisis hasil operasi dan mengatasi kesalahan (error) terkait operator.
#
# ## 1.3 Manfaat
# 1. Penguasaan fondasi pemrograman.
# 2. Peningkatan keterampilan praktis dalam menulis kode.
# 3. Pencegahan kesalahan logika kode.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# **1. Pengenalan Operator Python**
#
# Operator dalam Python adalah simbol khusus
# yang digunakan untuk melakukan suatu operasi
# terhadap nilai atau variabel, seperti operasi aritmatika, perbandingan, maupun logika.
# Python menyediakan berbagai jenis operator,
# di antaranya operator aritmatika, operator
# penugasan, operator perbandingan, operator
# logika, operator identitas, operator
# keanggotaan, dan operator bitwise. Dengan
# memahami operator, seorang pemrogram dapat
# menuliskan ekspresi dan logika program dengan
# lebih efisien dan mudah dipahami.
#
# **2. Konsep Operator Python**
#
# Operator merupakan simbol-simbol yang digunakan untuk melakukan operasi terhadap nilai atau variabel tertentu.Di dalam bahasa pemrograman, seperti Python, operator digunakan untuk mengolah data yang terdapat pada program, misalnya untuk menjumlahkan, membandingkan, atau menggabungkan nilai. Setiap operator memiliki simbol tertentu yang membedakannya dari operator lain. Jika simbol yang digunakan salah atau tidak sesuai, maka operator tersebut tidak dapat dijalankan oleh program sebagaimana mestinya. Dengan menggunakan operator, sebuah program dapat memproses, membandingkan, dan mengubah nilai yang tersimpan di dalam variabel.
#
# **3. Jenis Operator dalam Python**
#
# Ada 6 jenis operator dalam pemrograman yang wajib diketahui
#
#  a. Operator Aritmatika : Operator aritmatika digunakan untuk melakukan operasi matematika. Operator ini terdiri dari penjumlahan(+), pengurangan (-), perkalian (*), pembagian (/), pembagian bulat(//), sisa bagi (%), dan perpangkatan(**).
#
#  b. Operator Perbandingan : Operator pembandingan ini digunakan untuk membandingkan dua nilai. Operator ini juga dikenal dengan Operator relasi dan sering digunakan untuk membuat sebuah logika atau kondisi. Operator ini terdiri dari lebih besar dari (>), lebih kecil dari (<), lebih besar atau sama dengan (>=), lebih kecil dari atau sama dengan (<=), sama dengan (=), dan tidak sama dengan (!=).
#
#  c. Operator Logika : Operator logika digunakan untuk menggabungkan pernyataan bersyarat. Operator ini terdiri dari and/konjungsi (jika keduanya benar hasilnya benar), or /disfungsi (jika salah satunya salah atau kedua duanya benar maka hasilnya benar), not/negaasi (jika pernyataan itu  benar, maka hasilnya salah), XOR/ disfungsi ekslusif (jika salah satunya salah, maka hasilnya benar).
#
#  d. Operator assignment / Penugasan : Operator penugasan ini digunakan untuk memberikan tugas kepada variabel dan akhir hasil akhirnya akan disimpan lagi ke variabel tersebut. Operator ini terdiri dari pengisian (=), penjumlahan(+=), pengurangan(-=), perkalian(*=), pembagian(/=), pembagian bulat(//=), sisa bagi(%=), dan perpangkatan (**=).
#
#  e. Operator keanggotaan dan identitas: Operator keanggotaan digunakan untuk menentukan apakah suatu nilai merupakan anggota di dalam tipe data kontainer, seperti list, tuple, atau set. Operator ini terdiri dari dari in (di dalam anggota) dan not in ( tidak di dalam anggota). Operator Identitas digunakan untuk memeriksa apakah operand tersebut merujuk pada objek yang sama. Operator identitas terdiri dari is ( merujuk kepada objek yang sama) dan not is (tidak merujuk kepada objek yang sama). Perlu diingat bahwa operasi identitas berbeda dengan kesamaan, jika identitas (is) merujuk ke objek yang sama, sedangkan kesamaan (==) merujuk pada isi dari objek tersebut.
#
#  f. Operator Bitwise: Operator bitwise digunakan untuk memperlakukan operan sebagai urutan digit biner dan mengoperasikan bit demi bit. Operator ini terdiri dari bitwise AND (&), bitwise OR (|), bitwise NOT (~), bitwise XOR (^), bitwise pergeseran ke kanan (>>), dan bitwise dengan pergeseran ke kiri.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "aritmatika_2611532012"

# %%
# Buat file dengan nma aritmatika_NIM.py
# Buat program untuk operator aritmatika dalam python
# Nama variabel ditambah 4 digit nim terakhir contoh : angka1_1234
# Program ini menggunakan fungsi input()
# Nilai yagn dimasukkan akan dikonversi menjadi tipe data integer

angka1_2012 = int(input("Input angka 1: "))
angka2_2012 = int(input("Input angka 2: "))

# Penjumlahan
hasil_2012 = angka1_2012 + angka2_2012
print("\n0perator Penjumlahan")
print("Hasil = ", hasil_2012)

# Pengurangan
hasil_2012 = angka1_2012 - angka2_2012
print("\nOperator Pengurangan")
print("Hasil = ", hasil_2012)

# Perkalian 
hasil_2012 = angka1_2012 * angka2_2012
print("\nOperator Perkalian")
print("Hasil = ", hasil_2012)

# Pembagian, Pembagian Bilangan Bulat, dan Sisa Bagi
if angka2_2012 != 0:
    hasil_2012 = angka1_2012 / angka2_2012
    print("\nOperator Pembagian")
    print("Hasil = ", hasil_2012)

    hasil_2012 = angka1_2012 // angka2_2012
    print("\nOperator Pembagian Bulat")
    print("Hasil = ", hasil_2012)

    hasil_2012 = angka1_2012 % angka2_2012
    print("\nOperator Sisa bagi")
    print("Hasil = ", hasil_2012)
else:
    print("Angka kedua tidak boleh bernilai 0")

# Pangkat
hasil_2012 = angka1_2012 ** angka2_2012
print("\nOperator Pangkat")
print("Hasil = ", hasil_2012)
# Out:
# 0perator Penjumlahan
# Hasil =  10
#
# Operator Pengurangan
# Hasil =  2
#
# Operator Perkalian
# Hasil =  24
#
# Operator Pembagian
# Hasil =  1.5
#
# Operator Pembagian Bulat
# Hasil =  1
#
# Operator Sisa bagi
# Hasil =  2
#
# Operator Pangkat
# Hasil =  1296

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama yang terdiri dari baris 1 sampai baris 5 merupakan komentar untuk membuat program,Python tidak akan memproses bagian ini.
# 2. Bagian kedua yang terdiri dari baris 7 dan baris 8 merupakan bagian untuk mengiput nilai yang digunakan untuk melakukan operasi aritmatika.
# 3. Bagian ketiga yang terdiri dari baris 10 sampai baris 13 merupakan bagian progam untuk melakukan operasi penjumlahan.
# 4. Bagian keempat yang terdiri dari baris 15 sampai baris 18 merupakan bagian program untuk melakukan operasi pengurangan.
# 5. Bagian kelima yang terdiri dari baris 20 sampai baris 23 merupakan bagian program untuk melakukan operasi perkalian.
# 6. Bagian keenam yang terdiri dari baris 25 sampai baris 39 merupakan bagian program untuk melakukan operasi pembagian, pembagian bulat, serta sisa bagi. Jika nilai kedua tidak sama dengan 0, maka dapat dilakukan operasi pembagian, pembagian bulat, serta sisa bagi, tetapi jika nilai kedua sama dengan 0, maka tidak dapat dilakukan operasi tersebut.
# 7. Bagian ketujuh yang terdiri dari baris 41 sampai baris 44 merupakan bagian program untuk melakukan operasi perpangkatan.

# %% [markdown]
# ### 2.2.2 Program Driver "perbandingan_2611532012"

# %%
# Buat file dengan nama perbandingan_NIM.py
# Nama variabel ditambah 4 digit terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversikan menjadi tipe data integer
# Program operator perbandingan dalam Python

angka1_2012 = int(input("Input angka-1 ="))
angka2_2012 = int(input("Input angka-2 ="))

# Lebih besar sama dari
hasil_2012 = angka1_2012 > angka2_2012
print("\nOperator lebih besar dari")
print("angka1 > angka2 =", hasil_2012)

# Lebih kecil dari 
hasil_2012 = angka1_2012 < angka2_2012
print("\nOperator lebih kecil dari")
print("angka1 < angka2 =", hasil_2012)

# Lebih besar dari atau sama dengan 
hasil_2012 = angka1_2012 >= angka2_2012
print("\nOperator lebih besar dari atau sama dengan")
print("angka1 >= angka2 =", hasil_2012)

# Lebih kecil dari atau sama dengan
hasil_2012 = angka1_2012 <= angka2_2012
print("\nOperator lebih kecil dari atau sama dengan")
print("angka1 <= angka2 =", hasil_2012)

# Sama dengan 
hasil_2012 = angka1_2012 == angka2_2012
print("\nOperator sama dengan")
print("angka1 == angka2 =", hasil_2012)

# Tidak sama dengan 
hasil_2012 = angka1_2012 != angka2_2012
print("\nOperator tidak sama dengan")
print("angka1 != angka2 =", hasil_2012)

# Tambahan: Perbandingan berantai dalam Python
hasil_2012 = 0 < angka1_2012 < 100
print("0 < angka1 < 100 =", hasil_2012)

hasil_2012 = 0 < angka2_2012 < 100
print("0 < angka2 < 100 =", hasil_2012)
# Out:
# Operator lebih besar dari
# angka1 > angka2 = True
#
# Operator lebih kecil dari
# angka1 < angka2 = False
#
# Operator lebih besar dari atau sama dengan
# angka1 >= angka2 = True
#
# Operator lebih kecil dari atau sama dengan
# angka1 <= angka2 = False
#
# Operator sama dengan
# angka1 == angka2 = False
#
# Operator tidak sama dengan
# angka1 != angka2 = True
# 0 < angka1 < 100 = True
# 0 < angka2 < 100 = True

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama yang terdiri dari baris 1 sampai baris 5 merupakan komentar untuk membuat program, Python tidak akan memproses bagian ini.
# 2. Bagian kedua yang terdiri dari baris 7 dan baris 8 merupakan bagian untuk mengiput nilai yang digunakan untuk melakukan operasi perbandingan.
# 3. Bagian ketiga yang terdiri dari baris 10 sampai baris 13 merupakan bagian progam untuk melakukan operasi perbandingan lebih besar dari (>).
# 4. Bagian keempat yang terdiri dari baris 15 sampai baris 18 merupakan bagian program untuk melakukan operasi lebih kecil dari (<).
# 5. Bagian kelima yang terdiri dari baris 20 sampai baris 23 merupakan bagian program untuk melakukan operasi perbandingan lebih besar dari atau sama dengan (>=).
# 6. Bagian keenam yang terdiri dari baris 25 sampai baris 28 merupakan bagian program untuk melakukan operasi perbandingan lebih kecil atau sama dengan (<=).
# 7. Bagian ketujuh yang terdiri dari baris 30 sampai baris 33 merupakan bagian program untuk melakukan operasi perbandingan sama dengan (=).
# 8. Bagian kedelelapan yang terdiri dari baris 35 sampai baris 38 merupakan bagian program untuk melakukan operasi perbandingan tidak sama dengan (!=).
# 9. Bagian kesembilan yang terdiri dari baris ke 40 sampai baris ke 45 merupakan program untuk melakukan progran perbandingan berantai (0 < angka < 100).

# %% [markdown]
# ### 2.2.3 Program Driver "logika_2611532012"

# %%
# Buat file dengan nama logika_NIM.py
# Nama variabel ditambah 4 digit nim terakir contoh : a1_1234
# Program ini menggunakan fungsi input()
# Program operator logika dalam Python

# Memasukkan nilai boolean
# Input tidak peka terhadap huruf besar dan kecil
a1_2012 = input("Input nilai boolean-1 (true/false): ").strip().lower() == "true"
a2_2012 = input("Input nilai boolean-2 (true/false): ").strip().lower() == "true"

print("\nA1 =", a1_2012)
print("\nA2 =", a2_2012)   

# Konjungsi: bernilai True jika keduanya True
hasil_2012 = a1_2012 and a2_2012
print("\nKonjungsi (AND)")
print("A1 and A2 =", hasil_2012)

# Disjungsi: bernilai true jika salah satunya True
hasil_2012 = a1_2012 or a2_2012
print("\nDisjungsi (OR)")
print("A1 or A2 =", hasil_2012)

# Negasi A1: Membalikkan nilai A1
hasil_2012 = not a1_2012
print("\nNegasi A1 (NOT)")
print("not A1 =", hasil_2012)

# Negasi A2: Memabalikkan nilai A2
hasil_2012 =  not a2_2012
print("\nNegasi A2 (NOT)")
print("not A2 =", hasil_2012)

# XOR: bernilai True jika kedua nilai berbeda
hasil_2012 = a1_2012 != a2_2012
print("\nDisjungsi Eksklusif (XOR)")
print("A1 XOR A2 =", hasil_2012)
# Out:
# A1 = True
#
# A2 = False
#
# Konjungsi (AND)
# A1 and A2 = False
#
# Disjungsi (OR)
# A1 or A2 = True
#
# Negasi A1 (NOT)
# not A1 = False
#
# Negasi A2 (NOT)
# not A2 = True
#
# Disjungsi Eksklusif (XOR)
# A1 XOR A2 = True

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama yang terdiri dari baris 1 sampai baris 5 merupakan komentar untuk membuat program, Python tidak akan memproses bagian ini.
# 2. Bagian kedua yang terdiri dari baris 7 dan baris 8 merupakan bagian untuk memasukkan nilai yang digunakan dalam program assignment (memasukkan suatu nilai ke variabel).
# 3. Bagian ketiga yang terdiri dari baris 13 sampai baris 16 merupakan bagian untuk memproses program assignment biasa menggunakan simbol (=) dan menampilkan hasil dari proses tersebut.
# 4. Bagian keempat yang terdiri dari baris 18 sampai baris 22 merupakan bagian untuk memproses program assignment penjumlahan dengan simbol (+=) dan program akan menampilkan hasil dari proses tersebut.
# 5. Bagian kelima yang terdiri dari baris 24 sampai baris 28 merupakan bagian untuk memproses program assignment pengurangan dengan menggunakan simbol (-=) kemudian program akan menampilkan hasil dari proses tersebut.
# 6. Bagian keenam yang terdiri dari baris 30 sampai baris 34 merupakan bagian untuk memproses program assignment perkalian dengan menggunakan simbol (*=) kemudian program akan menampilkan hasil dari proses tersebut.
# 7. Bagian ketujuh yang terdiri dari baris 36 sampai baris 53 merupakan bagian untuk memproses program assignment pembagian dengan menggunakan simbol (/=), assignment pembagian bulat (//=), dan assignment sisa bagi kemudian program akan menampilkan hasil dari proses tersebut dengan syarat bahwa angka-2 tidak boleh sama dengan 0.Jika angka-2 sama dengan 0, maka program tidak dapat dijalankan .
# 8. Bagian kedelapan yang terdiri dari baris 55 sampai baris 58 merupakan bagian untuk memproses program assignment perpangkatan dengan simbol (**=) dan program akan menanmpilkan hasil dari proses tersebut.

# %% [markdown]
# ### 2.2.4 Program Driver "assignment_2611532012"

# %%
# Buat file dengan nama assignment_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator assignmernt dalam Python

angka1_2012 = int(input("Input angka-1: "))
angka2_2012 = int(input("Input angka-2: "))

print("\nNilai awal angka1 =", angka1_2012)
print("\nNilai angka2 =", angka2_2012)

# Assignment biasa 
hasil_2012= angka1_2012
print("\nAssignment biasa (=)")
print("Hasil = ", hasil_2012)

# Assignment penambahan 
hasil_2012 = angka1_2012
hasil_2012 += angka2_2012
print("\nAssignment penambahan (+=)")
print("Hasil =", hasil_2012)

# Assignment pengurangan
hasil_2012 = angka1_2012
hasil_2012 -= angka2_2012
print("\nAssignment pengurangan (-=)")
print("Hasil =", hasil_2012)

# Assignment perkalian 
hasil_2012 = angka1_2012
hasil_2012 *= angka2_2012
print("\nAssignment perkalian (*=)")
print("Hasil =", hasil_2012)

# Assignment pembagian, pembagian bulat, dan sisa bagi
if angka2_2012 != 0:
    hasil_2012 = angka1_2012
    hasil_2012 /= angka2_2012
    print("\nAssigment pembagian (/=)")
    print("Hasil =", hasil_2012)
    #Operator tambahan 
    hasil_2012 = angka1_2012
    hasil_2012 //= angka2_2012
    print("\nAssignment pembagian bulat (//=)")
    print("Hasil =", hasil_2012)
    hasil_2012 = angka1_2012
    hasil_2012 %= angka2_2012
    print("\nAssignment sisa bagi (%=)")
    print("Hasil =", hasil_2012)
else:
    print("\nPembagian tidak dapat dilakukan.")
    print("Angka kedua tidak boleh bernilai 0.")

# Operator tambahan: assignment perpangkatan
hasil_2012 = angka1_2012
hasil_2012 **= angka2_2012
print("Hasil =", hasil_2012)
# Out:
# Nilai awal angka1 = 10
#
# Nilai angka2 = 4
#
# Assignment biasa (=)
# Hasil =  10
#
# Assignment penambahan (+=)
# Hasil = 14
#
# Assignment pengurangan (-=)
# Hasil = 6
#
# Assignment perkalian (*=)
# Hasil = 40
#
# Assigment pembagian (/=)
# Hasil = 2.5
#
# Assignment pembagian bulat (//=)
# Hasil = 2
#
# Assignment sisa bagi (%=)
# Hasil = 2
# Hasil = 10000

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama yang terdiri dari baris 1 sampai baris 5 merupakan komentar untuk membuat program, Python tidak akan memproses bagian ini.
# 2. Bagian kedua yang terdiri dari baris 7 dan baris 8 merupakan bagian untuk memasukkan nilai yang digunakan dalam program assignment (memasukkan suatu nilai ke variabel).
# 3. Bagian ketiga yang terdiri dari baris 13 sampai baris 16 merupakan bagian untuk memproses program assignment biasa menggunakan simbol (=) dan menampilkan hasil dari proses tersebut.
# 4. Bagian keempat yang terdiri dari baris 18 sampai baris 22 merupakan bagian untuk memproses program assignment penjumlahan dengan simbol (+=) dan program akan menampilkan hasil dari proses tersebut.
# 5. Bagian kelima yang terdiri dari baris 24 sampai baris 28 merupakan bagian untuk memproses program assignment pengurangan dengan menggunakan simbol (-=) kemudian program akan menampilkan hasil dari proses tersebut.
# 6. Bagian keenam yang terdiri dari baris 30 sampai baris 34 merupakan bagian untuk memproses program assignment perkalian dengan menggunakan simbol (*=) kemudian program akan menampilkan hasil dari proses tersebut.
# 7. Bagian ketujuh yang terdiri dari baris 36 sampai baris 53 merupakan bagian untuk memproses program assignment pembagian dengan menggunakan simbol (/=), assignment pembagian bulat (//=), dan assignment sisa bagi kemudian program akan menampilkan hasil dari proses tersebut dengan syarat bahwa angka-2 tidak boleh sama dengan 0.Jika angka-2 sama dengan 0, maka program tidak dapat dijalankan .
# 8. Bagian kedelapan yang terdiri dari baris 55 sampai baris 58 merupakan bagian untuk memproses program assignment perpangkatan dengan simbol (**=) dan program akan menanmpilkan hasil dari proses tersebut.

# %% [markdown]
# ### 2.2.5 Program Driver "lainnya_2611532012"

# %%
# Buat file dengan nama lainnya_NIM.py
# Nama variabel ditambah4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()
# Program operator keanggotaan dan indetitas 

print("===================================")
print("1. OPERATOR KEANGGOTAAN")
print("===================================")

# Input beberapa data yang dipisahkan dengan koma
input_data_2012 = input("Masukkan beberapa angka, pisahkan dengan koma:")

# Mengubah input menjadi list integer
data_2012 = [int(angka.strip()) for angka in input_data_2012.split(",") ]

nilai_dicari_2012 = int(input("Masukkan angka yang ingin dicari:"))

# Operator in
hasil_2012 = nilai_dicari_2012 in data_2012
print("\nOperator keanggotaan IN")
print(nilai_dicari_2012, "in", data_2012, "=", hasil_2012)

# Operator not in
hasil_2012 = nilai_dicari_2012 not in data_2012
print("\nOperator keanggotaan NOT IN")
print(nilai_dicari_2012, "not in", data_2012, "=", hasil_2012)


print("\n===================================")
print("2. OPERATOR IDENTITAS")
print("===================================")

# Objek1 menggunakan list dari input pengguna
objek1_2012 = data_2012

# Objek2 menggunakan objek yang sama dengan objek 1
objek2_2012 = objek1_2012

# Objek3 memiliki isi sama, tetapi merupakan objek baru
objek3_2012 = data_2012.copy()

print("objek1 =", objek1_2012)
print("objek2 =", objek2_2012)
print("objek3 =", objek3_2012)

# Operator is
hasil_2012 = objek1_2012 is objek2_2012
print("\nOperator identitas IS")
print("objek1 is objek2 =", hasil_2012)

# Operator is not
hasil_2012 = objek1_2012 is not objek3_2012
print("\nOperator identitas IS NOT")
print("objek1 is not objek3 =", hasil_2012)

# Membandingkan identitas dan nilai 
print("\nPerbandingan identitas dan nilai")
print("objek1 is objek3 =", objek1_2012 is objek3_2012)
print("objek1 == objek3 =", objek1_2012 == objek3_2012)
# Out:
# ...
# 1. OPERATOR KEANGGOTAAN
# ...
#
# Operator keanggotaan IN
# 18 in [2, 5, 8] = False
#
# Operator keanggotaan NOT IN
# 18 not in [2, 5, 8] = True
#
# ...
# 2. OPERATOR IDENTITAS
# ...
# objek1 = [2, 5, 8]
# objek2 = [2, 5, 8]
# objek3 = [2, 5, 8]
#
# Operator identitas IS
# objek1 is objek2 = True
#
# Operator identitas IS NOT
# objek1 is not objek3 = True
#
# Perbandingan identitas dan nilai
# objek1 is objek3 = False
# objek1 == objek3 = True

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama yang terdiri dari baris 1 sampai baris 4 merupakan komentar untuk membuat program, Python tidak akan memproses bagian ini.
# 2. Bagian kedua yang terdiri dari baris 6 sampai baris 8 merupakan tampilan awal untuk program operator keanggotaan dan baris ke 10 sampai baris 16 merupakan program untuk memasukkan nilai data dan nilai data yang akan dicari yang akan digunakan dalam program operator ini
# 3. Bagian ketiga yang terdiri dari baris 18 sampat baris 21 merupakan bagian untuk membuat program operator in dengan mencari apakah data yang dicari tersebut terdapat di dalam data yang disimpan oleh program serta bagian ini akan menampilkan hasil dari program tersebut berupa data boolean.
# 4. Bagian keempat yang terdiri dari baris 23 sampai baris 26 merupakan bagian untuk membuat program operator not in dengan mencari apakah data yang dicari tersebut tidak terdapat di dalam data yang telaj disimpan oleh program serta bagian ini akan menampilkan hasil dari program tersebut berupa data Boolean.
# 5. Bagian kelima yang terdiri dari baris 29 sampai baris ke 31 merupakan tampilan awal untuk program operator identitas, baris 33 dan 34 merupakan baris yang dimana objek1 menggunakan list dari data yang diinputkan sebagai data yeng tersimpan dalam program, baris 36 dan 37 menggunakan objek2 yang sama dengan objek1, dan baris 39 dan 40 merupakan baris yang dimana objek3 memiliki isi yang sama dengan objek1, tetapi merupakan objek baru.
# 6. Bagian keenam yang terdiri dari baris 46 sampai baris 49 merupakan bagian untuk membuat program operator is dengan mencari tahu apakah objek1 menggunakan objek yang sama dengan objek2, serta program ini akan menampilkan hasil dari program tersebut menggunakan tipe data Boolean.
# 7. Bagian ketujuh yang terdiri dari baris 51 sampai baris 54 merupakan bagian untuk membuat program operator is not dengan mencari tahu apakah objek1 menggunakan objek yang berbeda dengan objek3, serta menampilkan hasil program tersebut dengan tipe data Boolean.
# 8. Bagian kedelapan yang terdiri dari baris 56 sampai baris 59 merupakan bagian untuk membuat program perbandingan antara operator is dengan operator (==) dengan mencari tahu apakah objek1 menggunakan objek yang sama dengan 3 dan apakah isi objek1 sama dengan isi objek3, serta program akan menampilkan hasil kedua program tersebut menggunakan tipe data Boolean.

# %% [markdown]
# ### 2.2.6 Program Driver "bitwise_2611532012"

# %%
# Buat file dengan nama bitwisse_NIM.py
# Nama variabel ditambah 4 digit terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()

print("\n===================================")
print("3. OPERATOR BITWISE")
print("===================================")

angka1_2012 = int(input("Masukkan angka bitwise-1 : "))
angka2_2012 = int(input("Masukkan angka bitwise-2 : "))

print("\nAngka dalam bentuk desimal dan biner")
print("angka1 =",angka1_2012, "| biner =", bin(angka1_2012))
print("angka2 =",angka2_2012, "| biner =", bin(angka2_2012))

# Bitwise AND 
hasil_2012 = angka1_2012 & angka2_2012
print("\nBitwse AND (&)")
print(angka1_2012, "&", angka2_2012)
print("Biner Hasil =", bin(hasil_2012))
print("Biner hasil (8 bit) =", format(hasil_2012, "08b"))

# Bitwise OR
hasil_2012 = angka1_2012 | angka2_2012
print("\nBitwise OR (|)")
print(angka1_2012, "|", angka2_2012, "=", hasil_2012)
print("Biner hasil =", bin(hasil_2012))
print("Biner hasil (8 bit) =", format(hasil_2012, "08b"))

# Bitwise XOR 
hasil_2012 = angka1_2012 ^ angka2_2012
print("\nBitwise XOR (^)")
print(angka1_2012, "^", angka2_2012, "=", hasil_2012)
print("Biner hasil =", bin(hasil_2012))
print("Biner hasil (8bit) ="), format(hasil_2012, "08b")

#Bitwise NOT 
hasil_2012 = ~angka1_2012
print("\nBitwise NOT (~)")
print("~", angka1_2012, "=", hasil_2012)
print("Biner hasil =", bin(hasil_2012))
print("Biner hasil (8bit) =", format(hasil_2012, "08b"))

# Bitwise geser kiri
jumlah_geser_2012 = int(input("\nMasukkan jumlah pergeseran bit: "))

hasil_2012 = angka1_2012 << jumlah_geser_2012
print("\nBitwise geser kiri (<<)")
print(angka1_2012, "<<", jumlah_geser_2012, "=", hasil_2012)
print("Biner hasil =", bin(hasil_2012))
print("Biner hasil (8bit) =", format(hasil_2012, "08b"))

# Bitwise geser kanan
hasil_2012 = angka1_2012 >> jumlah_geser_2012
print("\nBitwise geser kanan (>>)")
print(angka1_2012, ">>", jumlah_geser_2012, "=", hasil_2012)
print("Biner hasil =", bin(hasil_2012))
print("Biner hasil (8bit) =", format(hasil_2012, "08b"))
# Out:
# ...
# 3. OPERATOR BITWISE
# ...
#
# Angka dalam bentuk desimal dan biner
# angka1 = 7 | biner = 0b111
# angka2 = 4 | biner = 0b100
#
# Bitwse AND (&)
# 7 & 4
# Biner Hasil = 0b100
# Biner hasil (8 bit) = 00000100
#
# Bitwise OR (|)
# 7 | 4 = 7
# Biner hasil = 0b111
# Biner hasil (8 bit) = 00000111
#
# Bitwise XOR (^)
# 7 ^ 4 = 3
# Biner hasil = 0b11
# Biner hasil (8bit) =
#
# Bitwise NOT (~)
# ~ 7 = -8
# Biner hasil = -0b1000
# Biner hasil (8bit) = -0001000
#
# Bitwise geser kiri (<<)
# 7 << 2 = 28
# Biner hasil = 0b11100
# Biner hasil (8bit) = 00011100
#
# Bitwise geser kanan (>>)
# 7 >> 2 = 1
# Biner hasil = 0b1
# Biner hasil (8bit) = 00000001

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama yang terdiri dari baris 1 sampai baris 3 merupakan komentar untuk membuat program, Python tidak akan memproses bagian ini.
# 2. Bagian kedua yang terdiri dari baris 5 sampai baris 7 merupakan tampilan awal untuk program operator bitwise dan baris ke 9 sampai baris 10 merupakan program untuk memasukkan nilai data dan nilai data yang akan dicari yang akan digunakan dalam program operator ini
# 3. Bagian ketiga yang terdiri dari baris 12 sampat baris 14 merupakan bagian untuk membuat program angka dalam bentuk desimal serta dalam bentuk biner menggunakan bin() agar nilai desimal tersebut berubah menjadi bilangan biner.
# 4. Bagian keempat yang terdiri dari baris 16 sampai baris 21 merupakan bagian untuk membuat program operator bitwise (and(&)) dengan mencari hasil dari angka 1 & angka 2, kemudian hasil tersebut diubah ke dalam bentuk biner dengan format 8 bit.
# 5. Bagian kelima yang terdiri dari baris 23 sampai baris ke 28 merupakan bagian untuk membuat program operator bitwise (or(|)) dengan mencari hasil dari angka 1 | angka 2, kemudian hasil tersebut diubah ke dalam bentuk biner dengan format 8 bit.
# 6. Bagian keenam yang terdiri dari baris 30 sampai baris ke 35 merupakan bagian untuk membuat program operator bitwise (XOR(^) dengan mencari hasil dari angka 1 ^ angka 2, kemudian hasil tersebut diubah ke dalam bentuk biner dengan format 8 bit.
# 7. Bagian ketujuh yang terdiri dari baris 37 sampai baris 42 merupakan bagian untuk membuat program operator bitwise (not(~) dengan mencari hasil dari lawan dari angka 1, kemudian hasil tersebut diubah menjadi bentuk biner dengan format 8 bit.
# 8. Bagian kedelapan yang terdiri dari baris 44 sampai baris ke 51 merupakan bagian untuk membuat program operator bitwise (geser ke kiri (<<)) dengan mencari hasil dari angka tersebut yang telah diubah menjadi kode biner kemudian kode biner tersebut digeser ke kiri sejauh berapa angka yang diinput dan tambahkan biner 0 sebanyak angka yang diinput di belakangnya, hasil dari program tersebut diubah menjadi kode biner dengan format 8 bit.
# 9. Bagian kesembilan yang terdiri dari baris 53 sampai baris ke 58 merupakan bagian untuk membuat program operasi bitwise (geser ke kanan(>>)) dengan mencari hasil dari angka tersebut yang telah diubah menjadi kode biner kemudian kode biner tersebut digeser ke ke kanan sejauh berapa angka yang diinputkan dan menambahkan biner 0 sebanyak angka biner yang diinput tersebut di depannya, hasil dari program tersebut kemudian diubah menjadi biner dengan format 8 bit.

# %% [markdown]
# ### 2.2.7 Program Driver "tugas3_2611532012"

# %%
# Buat file dengan nama file tugas3_NIM.py
# Program sistem transaksi toko dengan menggunakan operator Python yang telah dipelajari
# Program ini menggunakan fungsi input()
# Menggunakan variabel ditambah 4 digit terakhir contoh : angka_1234

print("\n=== SISTEM TRANSAKSI TOKO ===")
# Memasukkan Data Pelanggan berupa string dan integer
nama_2012 = input("Masukkan Nama Pelanggan :")
status_2012 =input("Masukkan Status Pelanggan (member/non member) :")
total_belanja_2012 = int(input("Masukkan Total Belanja :"))
total_barang_2012 = int(input("Masukkan Total Barang : "))
kode_promo_2012 = input("Masukkan Kode Promo :")
print(" ")
# Cek Validasi (Operator Perbandingan, Operator Keanggotaan, dan Operator Logika)
print("\n=== HASIL VALIDASI ===")
# Menggunakan Operator perbandingan lebih besar dari atau sama dengan (=)
belanja_cukup_2012 = total_belanja_2012 >= 200000
print("Belanja >= Rp 200000 :", belanja_cukup_2012)
barang_cukup_2012 = total_barang_2012 >= 3
print("Jumlah Barang >= 3 :", barang_cukup_2012)
# Menggunakan operator perbandingan (==) yang mana kata yang diinput tidak diperhatikan huruf kapital. huruf kecil, dan spasi
member_2012 = status_2012.strip().lower() == "member"
print("Status Member :", member_2012)
# Menggunakan operator keanggotaan yang mana kata yang diinput tidak diperhatikan huruf kapital, huruf kecil, dan spasi
daftar_promo_2012 = ("GOHEMAT" ,"HEMAT10" ,"HEMATGO")
promo_tersedia_2012 = kode_promo_2012.strip().upper() in daftar_promo_2012
# Menggunakan Operator logika konjungsi (and)
print("Kode Promo Tersedia :", promo_tersedia_2012)
dapat_diskon_2012 = belanja_cukup_2012 and barang_cukup_2012
print("Mendapatkan Diskon :", dapat_diskon_2012 )
dapat_promo_2012 = member_2012 and promo_tersedia_2012
print("Mendapatkan Promo :", dapat_promo_2012)
print(" ")
# Perhitungan Diskon, Total Pembayaran, dan Rata - Rata Barang menggunakan Operator Aritmatika (perkalian(*) dan pengurangan(-))
print("\n=== HASIL PERHITUNGAN ===")
if dapat_diskon_2012:
    diskon_2012 = 0.03
else:
    diskon_2012 = 0
if dapat_promo_2012:
    promo_2012 = 0.10
else:
    promo_2012 = 0
total_diskon_2012 = total_belanja_2012 * diskon_2012
total_promo_2012 = total_belanja_2012 * promo_2012
total_pembayaran_2012 = total_belanja_2012 - total_diskon_2012 - total_promo_2012
rata2_barang_2012 = total_pembayaran_2012 / total_barang_2012
print("Diskon :", "Rp", int(total_diskon_2012))
print("Promo  :", "Rp", int(total_promo_2012))
print("Total Pembayaran :", "Rp", int(total_pembayaran_2012) )
print("Rata - Rata Harga Barang :", "Rp", int(rata2_barang_2012))
print(" ")
print("\n=== HAK AKSES===")
# Flag angka untuk masing masing kode
free_shipping_2012 = total_pembayaran_2012 >= 250000
Member_2012 = 0b0001 #1 
Diskon_2012 = 0b0010 #2
Free_shipping_2012 = 0b0100 #4
Promo_2012 = 0b1000 #8
kode_akses_2012 = 0
# Menentukan nilai kode akses dengan menggunakan operator assignment (|=)
if member_2012:
   kode_akses_2012 |= Member_2012
if dapat_diskon_2012:
   kode_akses_2012 |= Diskon_2012
if free_shipping_2012:
   kode_akses_2012 |= Free_shipping_2012
if dapat_promo_2012 :
   kode_akses_2012 |= Promo_2012
# Menampilkan kode 4 bit dari kode akses dan juga menampilkan apakah user tersebut mendapat benefit lainnya menggunakan tipe data boolean
print("Kode Hak Akses   :", format(kode_akses_2012, "04b"))
print("Member Access    :", bool(kode_akses_2012 & Member_2012))
print("Diskon Access    :", bool(kode_akses_2012 & Diskon_2012))
print("Free Shipping Access :", bool(kode_akses_2012 & Free_shipping_2012))
print("Promo Access     :", bool(kode_akses_2012 & Promo_2012))
print("")
# Cek Referensi Status Membere dengan menggunakan Operator Identitas
print("\n=== Cek Referensi Status Member ===")
referensi_status_2012 = member_2012         
hasil_2012 = referensi_status_2012 is member_2012 
print(" referensi status is member  :", hasil_2012)
 
print("\n=== Cek Objek Kode Akses ===")
kode_akses_lain_2012 = kode_akses_2012      
hasil_2012 = kode_akses_lain_2012 is kode_akses_2012
print("kode akses lain is kode akses :", hasil_2012)
# OPERASI BITWISE dengan bilangan biner format 4 bit serta menampikan bilangan desimal dari bilangan biner tersebut
print("\n=== OPERASI BITWISE===")
print("\n=== Kode Status Transaksi ===")
print(format(Member_2012, "04b"), "|", format(Diskon_2012,"04b"), "|", format(Free_shipping_2012, "04b"), "|", format(Promo_2012,"04b"))
print("Kode Biner   :", format(kode_akses_2012, "04b"))
print("Kode Desimal :", format(kode_akses_2012))
print("")
print("\n=== Pemeriksaan Status ===")
# Cek Member dengan menggunakan Operasi Bitwise (AND(&))
print("Cek member")
print(format(kode_akses_2012,"04b"), "&", format(Member_2012,"04b"))
Hasil_biner_2012 = kode_akses_2012 & Member_2012
print(format(Hasil_biner_2012,"04b"))
print("\nCek Promo")
print(format(kode_akses_2012, "04b"), "&", format(Promo_2012, "04b"))
hasil_biner_2012 = kode_akses_2012 & Promo_2012
print(format(hasil_biner_2012, "04b"))
# Perbandingan Status dengan menggunakan Operasi Bitwise (XOR (^))
print("\n ===Perbandingan Status ===")
kode_referensi_2012 = 0b1011
print("Kode Transaksi :", format(kode_akses_2012, "04b"))
print("Kode Referensi :", format(kode_referensi_2012, "04b"))
hasil_biner_2012 = kode_akses_2012 ^ kode_referensi_2012
print(format(kode_akses_2012 ^ kode_referensi_2012,"04b"))
print("Hasil Biner :", format(hasil_biner_2012,"04b"))
print("Hasil desimal :", hasil_biner_2012)
print(" ")
print("\n=== Selesai===")
# Out:
# === SISTEM TRANSAKSI TOKO ===
#
#
# === HASIL VALIDASI ===
# Belanja >= Rp 200000 : True
# Jumlah Barang >= 3 : True
# Status Member : True
# Kode Promo Tersedia : True
# Mendapatkan Diskon : True
# Mendapatkan Promo : True
#
#
# === HASIL PERHITUNGAN ===
# Diskon : Rp 7500
# Promo  : Rp 25000
# Total Pembayaran : Rp 217500
# Rata - Rata Harga Barang : Rp 43500
#
#
# === HAK AKSES===
# Kode Hak Akses   : 1011
# Member Access    : True
# Diskon Access    : True
# Free Shipping Access : False
# Promo Access     : True
#
#
# === Cek Referensi Status Member ===
#  referensi status is member  : True
#
# === Cek Objek Kode Akses ===
# kode akses lain is kode akses : True
#
# === OPERASI BITWISE===
#
# === Kode Status Transaksi ===
# 0001 | 0010 | 0100 | 1000
# Kode Biner   : 1011
# Kode Desimal : 11
#
#
# === Pemeriksaan Status ===
# Cek member
# 1011 & 0001
# 0001
#
# Cek Promo
# 1011 & 1000
# 1000
#
#  ===Perbandingan Status ===
# Kode Transaksi : 1011
# Kode Referensi : 1011
# 0000
# ...

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama yang terdiri dari baris 1 sampai baris 4 merupakan komentar untuk membuat program Sistem Transaksi Toko, Python tidak akan memproses bagian ini.
# 2. Bagian kedua yang terdiri dari baris 6merupakan tampilan awal untuk program sistem transaksi toko, baris 7 sampai baris 12 berisi data yang diinputkan oleh user yang akan dijalankan oleh program, dan baris 13 menampilkan baris kosong.
# 3. Bagian ketiga yang terdiri dari baris 14 sampat baris 32 merupakan bagian untuk melihat hasil validasi menggunakan operator perbandingan, operator keanggotaan dan operator logika kemudian program akan menampilkan hasil dari proses tersebut. Dan juga baris 33 menampilkan baris kosong.
# 4. Bagian keempat yang terdiri dari baris 34 sampai baris 51 merupakan bagian untuk mencari hasil perhitungan dari data yang telah diinputkan di bagian kedua menggunakan operator aritmatika dan percabangan, lalu program akan menampilkan hasil dari proses tersebut. Dan juga baris 52 menampilkan baris kosong.
# 5. Bagian kelima yang terdiri dari baris 53 sampai baris ke 75 merupakan bagian untuk melihat hak akses yang mana terdapat flag angka untuk masing masing kode.Kemudian untuk mendapatkan nilai kode akses menggunakan operator assignment (|=) agar kode tersebut berhasil didapat, lalu nilai kode akses tersebut diubah ke dalam bentuk biner dengan format 4 bit dan juga bagian ini juga menampilkan apakah user tersebut mendapatkan benefit lainnya.Dan baris 76 menampilkan baris kosong.
# 6. Bagian keenam yang terdiri dari baris 77 sampai baris ke 86 merupakan bagian untuk membuat program cek referensi status member dan objek kode akses apakah referensi status member dan objek kode akses tersebut menggunakan objek yang sama dengan member dan kode akses dan juga program akan menampilkan dari hasil tersebut.
# 7. Bagian ketujuh yang terdiri dari baris 87 sampai baris ke 92 merupakan bagian untuk membuat program operasi bitwise yang mana akan menampilkan kode biner 4 bit dari member, diskon, free shipping, dan promo. Dan juga bagian ini akan menampilkan kode biner 4 bit dan bilangan desimal dari kode akses.Dan baris ke 93 menampilkan baris kosong.
# 8. Bagian kedelapan yang terdiri dari baris 94 sampai baris 103 merupakan programpemeriksaan status dengan menggunakan operator bitwise (AND(&)) yang mana program ini menggunakan data kode akses dan data kode promo.Kemudian, program akan menampilkan hasil dari proses tersebut dalam kode biner dengan format 4 bit.
# 9. Bagian kesembilan yang terdiri dari baris 104 sampai baris 104 sampai baris 112 merupakan program perbandingan status dengan menggunakan operator bitwise (XOR(^)) yang mana perbandingan status ini menggunakan data kode akses dan referensi. Kemudian, program akan menampilkan hasil dari program tersebut berupa kode biner dengan format 4 bit dan bilangan desimal. Baris 113 menampilkan baris kosong dan baris 114 menampilkan tulisan selesai

# %% [markdown]
# ### 2.3 Pertanyaan Analisis

# %% [markdown]
# **Penjelasan :**
# 1. Jelaskan operator aritmatika apa saja yang digunakan dan bagaimana operator tersebut membantu menghitung transaksi.
#
# Ada beberapa operator aritmatika yang dipakai di bagian HASIL PERHITUNGAN:
# total_diskon_2012 = total_belanja_2012 * diskon_2012
# total_promo_2012 = total_belanja_2012 * promo_2012
# total_pembayaran_2012 = total_belanja_2012 - total_diskon_2012 - total_promo_2012
# rata2_barang_2012 = total_pembayaran_2012 / total_barang_2012
# Operator	Fungsi dalam program yaitu perkalian (*) digunakan untuk menghitung nominal diskon dan promo dari persentase (0.03 dan 0.10) dikali total belanja, pengurangan (-)	digunakan untuk mengurangi total belanja dengan diskon dan promo untuk mendapatkan total pembayaran akhir, dan pembagian (/) digunakan untuk membagi total pembayaran dengan jumlah barang untuk mendapatkan rata-rata harga per barang.Operator-operator ini yang membuat program bisa mengubah persentase diskon/promo menjadi nominal rupiah nyata, lalu menghitung berapa yang harus dibayar pelanggan.
#
# 2. Jelaskan perbedaan operator and, or, dan not berdasarkan penerapannya pada program.
#
# and digunakan apabila kedua pernyataan benar maka hasilnya benar dan apabila salah satunya salah maka hasilnya salah.
# or digunakan apabila salah satu pernyataan salah maka hasilnya tetap benar.
# not digunakan untuk membalikkan kebenaran dari suatu pernyataan.Jika pernyataan benar  maka hasilnya salah.
#
# 3. Jelaskan fungsi operator in dan not in pada pemeriksaan kode promo.
#
# Operator in mengecek apakah suatu nilai ada di dalam kumpulan data (list, tuple, atau string). Di sini, in mengecek apakah kode promo yang diketik pelanggan (setelah dibersihkan spasi dan diseragamkan huruf kapital) termasuk dalam daftar promo yang berlaku. Operator not in adalah kebalikannya, digunakan untuk  mengecek apakah suatu nilai tidak ada di dalam kumpulan data.
#
# 4. Apa perbedaan antara is dan == pada Python?
#
# == digunakan untuk membandingkan nilai dua objek apakah isinya sama.Sementara is digunakan untuk membandingkan identitas objek  apakah keduanya benar-benar objek yang sama persis di memori.
#
# 5. Jelaskan bagaimana operator bitwise digunakan untuk menentukan hak akses pelanggan.
#
# Member_2012 = 0b0001 #1
# Diskon_2012 = 0b0010 #2
# Free_shipping_2012 = 0b0100 #4
# Promo_2012 = 0b1000 #8
# kode_akses_2012 = 0
#   Setiap jenis hak akses direpresentasikan sebagai satu bit yang berbeda posisinya (0001, 0010, 0100, 1000).
# Operator |= (OR) dipakai untuk menyalakan bit tertentu tanpa mematikan bit lain yang sudah menyala — sehingga satu angka (kode_akses_2012) bisa menyimpan beberapa status sekaligus.Untuk mengecek kembali status tertentu dipakailah operator AND (&).Operator ^ (XOR) dipakai untuk membandingkan kode transaksi dengan kode referensi — hasilnya menunjukkan bit mana saja yang berbeda antara keduanya.
#
# 6. Jelaskan alur program mulai dari input hingga menghasilkan total pembayaran dan status promo.
#
# Input data — nama, status pelanggan, total belanja, jumlah barang, kode promo (semua lewat input()).
# Validasi — mengecek apakah belanja ≥ Rp200.000, barang ≥ 3, status member, dan kode promo tersedia dalam daftar.
# Penentuan kelayakan — dapat_diskon_2012 dan dapat_promo_2012 ditentukan dari hasil validasi di atas.
# Perhitungan — jika layak, diskon diset 3% dan promo 10% dari total belanja; nominalnya dihitung lalu dikurangkan dari total belanja untuk mendapatkan total_pembayaran_2012.
# Rata-rata harga — total pembayaran dibagi jumlah barang.
# Hak akses — status member, diskon, free shipping, dan promo dikonversi jadi kode biner memakai bitwise OR.
# Verifikasi & perbandingan — kode akses dicek ulang pakai AND, dibandingkan dengan kode referensi pakai XOR.
#
# 7.  Identifikasi minimal satu kondisi dalam program yang menghasilkan True dan satu kondisi yang menghasilkan False.
#
# Menggunakan data Rusdy (belanja Rp250.000, 5 barang, member, kode promo HEMAT10):
# Kondisi bernilai True:
#   belanja_cukup_2012 = total_belanja_2012 >= 200000
#   250000 >= 200000 → True
#
# Kondisi bernilai False:
#   free_shipping_2012 = total_pembayaran_2012 >= 250000
#   217500 >= 250000 → False
#
# Karena total pembayaran setelah diskon & promo (Rp217.500) tetapi tidak mencapai batas minimum Rp250.000 untuk mendapat gratis ongkir.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan kegiatan praktikum Algoritma dan Pemrograman yang telah dilakukan, dapat diperoleh beberapa kesimpulan sebagai berikut:
#
# **1. Python menyediakan enam jenis operator utama yaiu aritmatika, perbandingan,
# logika, assignment (penugasan), keanggotaan & identitas, serta bitwise  yang
# masing-masing memiliki simbol dan fungsi spesifik untuk mengolah nilai dan
# variabel dalam program.**
#
# **2. Operator logika (and, or, not) dan operator perbandingan bekerja sama untuk
# membentuk kondisi kompleks, seperti terlihat pada program validasi transaksi
# yang mengecek beberapa syarat sekaligus (misalnya "member" DAN "kode promo valid")
# sebelum menentukan hasil akhir.**
#
# **3. Operator identitas (is, is not) berbeda dengan operator kesamaan (==): is
# memeriksa apakah dua variabel menunjuk ke objek yang sama persis di memori,
# sedangkan == memeriksa apakah isi/nilainya sama — dua objek yang isinya identik
# belum tentu merupakan objek yang sama (dibuktikan objek1 is objek3 bernilai
# False, tetapi objek1 == objek3 bernilai True).**
#
# **4. Operator bitwise (&, |, ^, ~, <<, >>) berguna untuk merepresentasikan dan
# mengelola beberapa status sekaligus dalam satu bilangan biner, seperti pada
# program hak akses pelanggan yang menggabungkan status member, diskon, free
# shipping, dan promo dalam satu kode akses menggunakan operator OR (|=), lalu
# memeriksanya kembali dengan operator AND (&).**
#
# **5. Kombinasi seluruh jenis operator memungkinkan pembuatan program aplikatif
# yang realistis, seperti yang ditunjukkan pada program Sistem Transaksi Toko
# (tugas3_2012) yang berhasil mengintegrasikan operator aritmatika, perbandingan,
# logika, keanggotaan, identitas, dan bitwise dalam satu alur program yang utuh,
# sehingga tujuan praktikum untuk memahami dan mengimplementasikan operator
# Python tercapai.**

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Ahmad Muhardian,"Belajar Pemrograman Python: Mengenal 6 Jenis Operator dalam Python.[2014].[Online].Tersedia : https://www.petanikode.com/python-operator/#google_vignette [19 September 2026]
#
#
# [2] Jan Egil Refsnes, "Python Operators".[2018].[Online].Tersedia : https://www.w3schools.com/python/python_operators.asp [19 September 2026]
#
# [3] Leodanis Pozo Ramos , "Operator dan Ekspresi dalam Python ,".[2025].[Online].Tersedia :https://realpython.com/python-operators-expressions/#getting-started-with-operators-and-expressions [19 September 2026]
